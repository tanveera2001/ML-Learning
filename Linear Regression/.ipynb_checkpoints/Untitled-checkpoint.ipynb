# %%
# Importing the libraries
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset and extrating the indipendent and dependent variables
companies = pd.read_csv("E:/ML-Learning/Linear Regression/1000_Companies.csv")

x = companies.iloc[:, :-1]
y = companies.iloc[:, 4]

companies.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Data visualization (Heat Map)
sns.heatmap(companies.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
# Encoding categorical data
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(
transformers = [
    ("encoder", OneHotEncoder(), [3])
    ],
    remainder='passthrough'

)

x = ct.fit_transform(x)

# %%
# Avooiding the Dummy variable Trap
x = x[:, 1:]

# %%
# Splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)
